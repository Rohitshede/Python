# %% [markdown]
# # Pandas

# %% [markdown]
# ## What is Pandas?
#
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.
#
# The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# ## Why Use Pandas?
#
# Pandas allows us to analyze big data and make conclusions based on statistical theories.
#
# Pandas can clean messy data sets, and make them readable and relevant.
#
# Relevant data is very important in data science.

# %% [markdown]
# ## What Can Pandas Do?
# Pandas gives you answers about the data. Like:
#
# * Is there a correlation between two or more columns?
# * What is average value?
# * Max value?
# * Min value?
#
# Pandas are also able to delete rows that are not relevant, or contains wrong values, like empty or NULL values. This is called cleaning the data.

# %%
import pandas as pd

print("Current Pandas version is:", pd.__version__)
# Out:
# Current Pandas version is: 1.5.3

# %% [markdown]
# ## What is a Series?
# A Pandas Series is like a column in a table.
#
# It is a one-dimensional array holding data of any type.

# %%
x = pd.Series([1,2,3,4,5])

print(x)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
z = [100,200,300,400,500]

a = pd.Series(z, index = ['a','b','c','d','e'])

print(a)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %%
g = [1,2,3,4,5]
a = pd.Series(g, index = [10,20,30,40,50])

print(a)
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# dtype: int64

# %%
#  Key/Value objects as series
emp = {1 : 'Sahil', 2 : 'Rohit', 3 : 'Tejas'}

z = pd.Series(emp)
print(z)
# Out:
# 1    Sahil
# 2    Rohit
# 3    Tejas
# dtype: object

# %%
runs = {
    'Day 1' : 190,
    'Day 2' : 184,
    'Day 3' : 210
}

a = pd.Series(runs)
a
# Out:
# Day 1    190
# Day 2    184
# Day 3    210
# dtype: int64

# %%
a['Day 1']
# Out:
# 190

# %%
# Accesing multiple elements
z = pd.Series(runs, index = ['Day1', 'Day3'])

print(z)
# Out:
# Day1   NaN
# Day3   NaN
# dtype: float64

# %% [markdown]
# ## What is a DataFrame?
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
Data = {
    'Marks' : [70,82,78,90,88],
    'Student' : ['Rohit', 'Sahil', 'Ronit', 'Tejas', 'Abhi']
}

x = pd.DataFrame(Data)

print(x)
# Out:
#    Marks Student
# 0     70   Rohit
# 1     82   Sahil
# 2     78   Ronit
# 3     90   Tejas
# 4     88    Abhi

# %% [markdown]
# ## Locating a row

# %%
# First way
x.loc[0::2]
# Out:
#    Marks Student
# 0     70   Rohit
# 2     78   Ronit
# 4     88    Abhi

# %%
# Second way
x.loc[[0,2,4]]
# Out:
#    Marks Student
# 0     70   Rohit
# 2     78   Ronit
# 4     88    Abhi

# %% [markdown]
# ## Named indices

# %%
Data = {
    'Marks' : [70,82,78,90,88],
    'Student' : ['Rohit', 'Sahil', 'Ronit', 'Tejas', 'Abhi']
}

x = pd.DataFrame(Data, index = [1,2,3,4,5])

x
# Out:
#    Marks Student
# 1     70   Rohit
# 2     82   Sahil
# 3     78   Ronit
# 4     90   Tejas
# 5     88    Abhi

# %% [markdown]
# ## Load Files Into a DataFrame
#
# If your data sets are stored in a file, Pandas can load them into a DataFrame.

# %%
import pandas as pd
import openpyxl as op

res = pd.read_excel('D:\Machine_Learning\Data sets\Result.xlsx')

res
# Out:
#         Name  Maths  Science  English  Marathi  Hitory  Geography
# 0      Rohit    NaN     67.0     77.0      NaN    78.0       89.0
# 1      Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2      Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3      Ronit   98.0     23.0     76.0      NaN    34.0       98.0
# 4       Abhi   65.0      NaN     67.0     55.0     NaN       65.0
# 5     Deepak   67.0     89.0     98.0     67.0    23.0        NaN
# 6     Aniket   34.0     76.0     65.0     34.0     NaN       56.0
# 7      Rahul   65.0     67.0     56.0      NaN    78.0       78.0
# 8     Vishal   23.0     98.0      NaN     23.0    12.0       12.0
# 9      Suraj   56.0      NaN      NaN     78.0    34.0       90.0
# 10    Pramod    NaN     78.0     89.0     89.0    67.0        NaN
# 11    Dhiraj   89.0      NaN     76.0     76.0    34.0       90.0
# 12    Ganesh   54.0     67.0      NaN     67.0    65.0       89.0
# 13     Umesh   98.0     34.0     98.0      NaN     NaN       76.0
# 14     Omkar   55.0     65.0     65.0     65.0     NaN       67.0
# 15     Sujay   67.0     23.0     23.0     67.0    89.0        NaN
# 16    Aakash   34.0     56.0     56.0     34.0     NaN       65.0
# 17   Swapnil   65.0      NaN     78.0      NaN    67.0       56.0
# 18     Kunal    NaN     12.0      NaN     23.0     NaN       65.0
# 19     Kisan    NaN      NaN     90.0     56.0    65.0       34.0
# 20   Saurabh    NaN     65.0     34.0     78.0    34.0        NaN
# 21       Sid   56.0      NaN     89.0     89.0    67.0       77.0
# 22      Abhi   89.0     66.0      NaN     76.0    34.0       90.0
# 23   Kshitij   54.0     67.0     67.0      NaN    65.0       89.0
# 24   Samarth    NaN     34.0     98.0     98.0     NaN       76.0
# 25   Sarthak   55.0     65.0     65.0     65.0    56.0        NaN
# 26    Nilesh   67.0     23.0     23.0     67.0     NaN       98.0
# 27     Vinod   34.0     56.0     56.0      NaN    76.0       65.0
# 28    Mahesh   65.0     78.0      NaN     65.0    67.0       56.0
# 29    Yogesh    NaN      NaN     12.0     23.0     NaN       65.0
# 30   Shubham    NaN     34.0     90.0     56.0    65.0       34.0
# 31    Balaji    NaN      NaN     77.0     56.0    78.0        NaN
# 32  Vaishnav   76.0      NaN      NaN     89.0    66.0       76.0
# 33    Pratil   67.0     65.0     89.0      NaN    67.0       67.0
# 34       Vir   98.0      NaN     76.0     98.0     NaN       98.0
# 35   Vinayak   65.0      NaN     67.0     55.0    65.0        NaN
# 36    Rugved   67.0     89.0     98.0     67.0     NaN       23.0
# 37    Ranvir   34.0     76.0     65.0      NaN    56.0       56.0
# 38    Rajesh    NaN     67.0      NaN     65.0    78.0       78.0
# 39    Pratap   23.0      NaN     65.0     23.0    12.0       12.0

# %%
res.head()
# Out:
#     Name  Maths  Science  English  Marathi  Hitory  Geography
# 0  Rohit    NaN     67.0     77.0      NaN    78.0       89.0
# 1  Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2  Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3  Ronit   98.0     23.0     76.0      NaN    34.0       98.0
# 4   Abhi   65.0      NaN     67.0     55.0     NaN       65.0

# %%
res.tail()
# Out:
#        Name  Maths  Science  English  Marathi  Hitory  Geography
# 35  Vinayak   65.0      NaN     67.0     55.0    65.0        NaN
# 36   Rugved   67.0     89.0     98.0     67.0     NaN       23.0
# 37   Ranvir   34.0     76.0     65.0      NaN    56.0       56.0
# 38   Rajesh    NaN     67.0      NaN     65.0    78.0       78.0
# 39   Pratap   23.0      NaN     65.0     23.0    12.0       12.0

# %%
print(res.to_string())
# Out:
#         Name  Maths  Science  English  Marathi  Hitory  Geography
# 0      Rohit    NaN     67.0     77.0      NaN    78.0       89.0
# 1      Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2      Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3      Ronit   98.0     23.0     76.0      NaN    34.0       98.0
# 4       Abhi   65.0      NaN     67.0     55.0     NaN       65.0
# 5     Deepak   67.0     89.0     98.0     67.0    23.0        NaN
# 6     Aniket   34.0     76.0     65.0     34.0     NaN       56.0
# 7      Rahul   65.0     67.0     56.0      NaN    78.0       78.0
# 8     Vishal   23.0     98.0      NaN     23.0    12.0       12.0
# 9      Suraj   56.0      NaN      NaN     78.0    34.0       90.0
# 10    Pramod    NaN     78.0     89.0     89.0    67.0        NaN
# 11    Dhiraj   89.0      NaN     76.0     76.0    34.0       90.0
# 12    Ganesh   54.0     67.0      NaN     67.0    65.0       89.0
# 13     Umesh   98.0     34.0     98.0      NaN     NaN       76.0
# 14     Omkar   55.0     65.0     65.0     65.0     NaN       67.0
# 15     Sujay   67.0     23.0     23.0     67.0    89.0        NaN
# 16    Aakash   34.0     56.0     56.0     34.0     NaN       65.0
# 17   Swapnil   65.0      NaN     78.0      NaN    67.0       56.0
# 18     Kunal    NaN     12.0      NaN     23.0     NaN       65.0
# 19     Kisan    NaN      NaN     90.0     56.0    65.0       34.0
# 20   Saurabh    NaN     65.0     34.0     78.0    34.0        NaN
# 21       Sid   56.0      NaN     89.0     89.0    67.0       77.0
# 22      Abhi   89.0     66.0      NaN     76.0    34.0       90.0
# 23   Kshitij   54.0     67.0     67.0      NaN    65.0       89.0
# 24   Samarth    NaN     34.0     98.0     98.0     NaN       76.0
# 25   Sarthak   55.0     65.0     65.0     65.0    56.0        NaN
# 26    Nilesh   67.0     23.0     23.0     67.0     NaN       98.0
# 27     Vinod   34.0     56.0     56.0      NaN    76.0       65.0
# 28    Mahesh   65.0     78.0      NaN     65.0    67.0       56.0
# 29    Yogesh    NaN      NaN     12.0     23.0     NaN       65.0
# 30   Shubham    NaN     34.0     90.0     56.0    65.0       34.0
# 31    Balaji    NaN      NaN     77.0     56.0    78.0        NaN
# 32  Vaishnav   76.0      NaN      NaN     89.0    66.0       76.0
# 33    Pratil   67.0     65.0     89.0      NaN    67.0       67.0
# 34       Vir   98.0      NaN     76.0     98.0     NaN       98.0
# 35   Vinayak   65.0      NaN     67.0     55.0    65.0        NaN
# 36    Rugved   67.0     89.0     98.0     67.0     NaN       23.0
# 37    Ranvir   34.0     76.0     65.0      NaN    56.0       56.0
# 38    Rajesh    NaN     67.0      NaN     65.0    78.0       78.0
# 39    Pratap   23.0      NaN     65.0     23.0    12.0       12.0

# %%
res.isnull().sum()
# Out:
# Name          0
# Maths        10
# Science      13
# English       9
# Marathi       9
# Hitory       11
# Geography     7
# dtype: int64

# %%
res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       40 non-null     object
#  1   Maths      30 non-null     float64
#  2   Science    27 non-null     float64
#  3   English    31 non-null     float64
#  4   Marathi    31 non-null     float64
#  5   Hitory     29 non-null     float64
#  6   Geography  33 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.3+ KB

# %% [markdown]
# ## Data Cleaning
# Data cleaning means fixing bad data in your data set.
#
# Bad data could be:
#
# * Empty cells
# * Data in wrong format
# * Wrong data
# * Duplicates

# %%
cust = pd.read_excel("D:\Machine_Learning\Data sets\Customers.xlsx")

cust
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [2000 rows x 8 columns]

# %%
x = cust.isnull().sum()
x
# Out:
# CustomerID                 0
# Gender                     0
# Age                        0
# Annual Income ($)          0
# Spending Score (1-100)     0
# Profession                35
# Work Experience            0
# Family Size                0
# dtype: int64

# %%
cust_1 = cust.dropna()
cust_1
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# 0        Healthcare                1            4
# 1          Engineer                3            3
# 2          Engineer                1            1
# 3            Lawyer                0            2
# 4     Entertainment                2            6
# ...             ...              ...          ...
# 1995         Artist                8            7
# 1996         Doctor                7            7
# 1997     Healthcare                9            2
# 1998      Executive                7            2
# 1999  Entertainment                5            2
#
# [1965 rows x 8 columns]

# %%
cust.sort_values(by= ['Age', 'Annual Income ($)']).head(10)
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 211          212  Female    0              22000                      92
# 228          229    Male    0              33000                      64
# 440          441  Female    0              57373                      29
# 1271        1272  Female    0              61228                      81
# 443          444  Female    0              68761                      16
# 1917        1918  Female    0              73128                      74
# 1562        1563  Female    0              94014                      53
# 1925        1926  Female    0             105935                      46
# 1757        1758    Male    0             108169                      24
# 821          822  Female    0             116759                      28
#
#          Profession  Work Experience  Family Size
# 211          Artist                2            1
# 228       Marketing                1            1
# 440             NaN                0            7
# 1271  Entertainment                1            6
# 443          Lawyer                1            4
# 1917         Artist                7            5
# 1562       Engineer                9            5
# 1925         Doctor                4            5
# 1757      Executive               10            3
# 821       Marketing                7            3

# %%
cust_1.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income ($)         0
# Spending Score (1-100)    0
# Profession                0
# Work Experience           0
# Family Size               0
# dtype: int64

# %% [markdown]
# ## Empty Cells
# Empty cells can potentially give you a wrong result when you analyze data
#
# ## Remove Rows
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This is usually OK, since data sets can be very big, and removing a few rows will not have a big impact on the result.

# %%
res_1 = res.copy()

res_1.fillna(10001, inplace = True)

res_1.head()
# Out:
#     Name    Maths  Science  English  Marathi   Hitory  Geography
# 0  Rohit  10001.0     67.0     77.0  10001.0     78.0       89.0
# 1  Sahil     76.0  10001.0     90.0     89.0     66.0       76.0
# 2  Tejas     67.0     65.0  10001.0     54.0     67.0       67.0
# 3  Ronit     98.0     23.0     76.0  10001.0     34.0       98.0
# 4   Abhi     65.0  10001.0     67.0     55.0  10001.0       65.0

# %%
res.isnull().sum()
# Out:
# Name          0
# Maths        10
# Science      13
# English       9
# Marathi       9
# Hitory       11
# Geography     7
# dtype: int64

# %%
res.describe()
# Out:
#           Maths    Science    English    Marathi     Hitory  Geography
# count  30.00000  27.000000  31.000000  31.000000  29.000000  33.000000
# mean   62.10000  59.444444  70.161290  62.806452  57.413793  67.666667
# std    20.68541  22.493304  22.734844  21.965760  20.770029  23.211886
# min    23.00000  12.000000  12.000000  23.000000  12.000000  12.000000
# 25%    54.25000  45.000000  65.000000  55.000000  34.000000  56.000000
# 50%    65.00000  65.000000  76.000000  65.000000  65.000000  67.000000
# 75%    67.00000  71.500000  89.000000  77.000000  67.000000  89.000000
# max    98.00000  98.000000  98.000000  98.000000  89.000000  98.000000

# %%
res_1.isnull().sum()
# Out:
# Name         0
# Maths        0
# Science      0
# English      0
# Marathi      0
# Hitory       0
# Geography    0
# dtype: int64

# %%
res_1.describe()
# Out:
#               Maths       Science     English       Marathi        Hitory  \
# count     40.000000     40.000000     40.0000     40.000000     40.000000
# mean    2546.825000   3290.450000   2304.6000   2298.900000   2791.900000
# std     4358.532474   4715.729619   4199.8195   4202.926696   4496.549844
# min       23.000000     12.000000     12.0000     23.000000     12.000000
# 25%       55.750000     65.000000     65.0000     56.000000     62.750000
# 50%       67.000000     71.500000     77.5000     67.000000     67.000000
# 75%     2573.750000  10001.000000     98.0000     98.000000  10001.000000
# max    10001.000000  10001.000000  10001.0000  10001.000000  10001.000000
#
#           Geography
# count     40.000000
# mean    1806.000000
# std     3822.480427
# min       12.000000
# 25%       65.000000
# 50%       76.000000
# 75%       92.000000
# max    10001.000000

# %% [markdown]
# ## Replace only for specified columns

# %%
res.head()
# Out:
#     Name  Maths  Science  English  Marathi  Hitory  Geography
# 0  Rohit    NaN     67.0     77.0      NaN    78.0       89.0
# 1  Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2  Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3  Ronit   98.0     23.0     76.0      NaN    34.0       98.0
# 4   Abhi   65.0      NaN     67.0     55.0     NaN       65.0

# %%
res['Marathi'].fillna(1009, inplace = True)

res.head()
# Out:
#     Name  Maths  Science  English  Marathi  Hitory  Geography
# 0  Rohit    NaN     67.0     77.0   1009.0    78.0       89.0
# 1  Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2  Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3  Ronit   98.0     23.0     76.0   1009.0    34.0       98.0
# 4   Abhi   65.0      NaN     67.0     55.0     NaN       65.0

# %% [markdown]
# ## Replace using Mean, Median or Mode

# %%
import pandas as pd

data = res 
data.head()
# Out:
#     Name  Maths  Science  English  Marathi  Hitory  Geography
# 0  Rohit    NaN     67.0     77.0   1009.0    78.0       89.0
# 1  Sahil   76.0      NaN     90.0     89.0    66.0       76.0
# 2  Tejas   67.0     65.0      NaN     54.0    67.0       67.0
# 3  Ronit   98.0     23.0     76.0   1009.0    34.0       98.0
# 4   Abhi   65.0      NaN     67.0     55.0     NaN       65.0

# %% [markdown]
# ## Creating new column from existing column

# %%
res_1.head()
# Out:
#     Name    Maths  Science  English  Marathi   Hitory  Geography
# 0  Rohit  10001.0     67.0     77.0  10001.0     78.0       89.0
# 1  Sahil     76.0  10001.0     90.0     89.0     66.0       76.0
# 2  Tejas     67.0     65.0  10001.0     54.0     67.0       67.0
# 3  Ronit     98.0     23.0     76.0  10001.0     34.0       98.0
# 4   Abhi     65.0  10001.0     67.0     55.0  10001.0       65.0

# %%
res_1["Algebra"] = res_1["Geography"] * 1.5

res_1.head()
# Out:
#     Name    Maths  Science  English  Marathi   Hitory  Geography  Algebra
# 0  Rohit  10001.0     67.0     77.0  10001.0     78.0       89.0    133.5
# 1  Sahil     76.0  10001.0     90.0     89.0     66.0       76.0    114.0
# 2  Tejas     67.0     65.0  10001.0     54.0     67.0       67.0    100.5
# 3  Ronit     98.0     23.0     76.0  10001.0     34.0       98.0    147.0
# 4   Abhi     65.0  10001.0     67.0     55.0  10001.0       65.0     97.5

# %%
res_1["Total"] = res_1["Maths"] + res_1["Science"] + res_1["English"] + res_1["Marathi"] + res_1["Hitory"] + res_1["Geography"] + res_1["Algebra"]

res_1.head()
# Out:
#     Name    Maths  Science  English  Marathi   Hitory  Geography  Algebra  \
# 0  Rohit  10001.0     67.0     77.0  10001.0     78.0       89.0    133.5
# 1  Sahil     76.0  10001.0     90.0     89.0     66.0       76.0    114.0
# 2  Tejas     67.0     65.0  10001.0     54.0     67.0       67.0    100.5
# 3  Ronit     98.0     23.0     76.0  10001.0     34.0       98.0    147.0
# 4   Abhi     65.0  10001.0     67.0     55.0  10001.0       65.0     97.5
#
#      Total
# 0  20446.5
# 1  10512.0
# 2  10421.5
# 3  10477.0
# 4  20351.5

# %%
# Renaming columns
res_rename = res.rename(columns={"Hitory": "History"})

res_rename.head()
# Out:
#     Name  Maths  Science  English  Marathi  History  Geography
# 0  Rohit    NaN     67.0     77.0   1009.0     78.0       89.0
# 1  Sahil   76.0      NaN     90.0     89.0     66.0       76.0
# 2  Tejas   67.0     65.0      NaN     54.0     67.0       67.0
# 3  Ronit   98.0     23.0     76.0   1009.0     34.0       98.0
# 4   Abhi   65.0      NaN     67.0     55.0      NaN       65.0

# %% [markdown]
# ## Titanic dataset 1

# %%
import pandas as pd

titanic_df = pd.read_csv("https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv")

titanic_df.head(20)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                             Mr. Owen Harris Braund
# 1          1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2          1       3                              Miss. Laina Heikkinen
# 3          1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4          0       3                            Mr. William Henry Allen
# 5          0       3                                    Mr. James Moran
# 6          0       1                             Mr. Timothy J McCarthy
# 7          0       3                      Master. Gosta Leonard Palsson
# 8          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9          1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10         1       3                     Miss. Marguerite Rut Sandstrom
# 11         1       1                            Miss. Elizabeth Bonnell
# 12         0       3                      Mr. William Henry Saundercock
# 13         0       3                         Mr. Anders Johan Andersson
# 14         0       3                Miss. Hulda Amanda Adolfina Vestrom
# 15         1       2                     Mrs. (Mary D Kingcome) Hewlett
# 16         0       3                                Master. Eugene Rice
# 17         1       2                        Mr. Charles Eugene Williams
# 18         0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# 19         1       3                             Mrs. Fatima Masselmani
#
#        Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0     male  22.0                        1                        0   7.2500
# 1   female  38.0                        1                        0  71.2833
# 2   female  26.0                        0                        0   7.9250
# 3   female  35.0                        1                        0  53.1000
# 4     male  35.0                        0                        0   8.0500
# 5     male  27.0                        0                        0   8.4583
# 6     male  54.0                        0                        0  51.8625
# 7     male   2.0                        3                        1  21.0750
# 8   female  27.0                        0                        2  11.1333
# 9   female  14.0                        1                        0  30.0708
# 10  female   4.0                        1                        1  16.7000
# 11  female  58.0                        0                        0  26.5500
# 12    male  20.0                        0                        0   8.0500
# 13    male  39.0                        1                        5  31.2750
# 14  female  14.0                        0                        0   7.8542
# 15  female  55.0                        0                        0  16.0000
# 16    male   2.0                        4                        1  29.1250
# 17    male  23.0                        0                        0  13.0000
# 18  female  31.0                        1                        0  18.0000
# 19  female  22.0                        0                        0   7.2250

# %%
titanic_df.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# max                   6.000000  512.32920

# %%
titanic_df.isnull().sum()
# Out:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64

# %%
titanic_df.sum()
# Out:
# Survived                                                                 342
# Pclass                                                                  2045
# Name                       Mr. Owen Harris BraundMrs. John Bradley (Flore...
# Sex                        malefemalefemalefemalemalemalemalemalefemalefe...
# Age                                                                 26141.17
# Siblings/Spouses Aboard                                                  466
# Parents/Children Aboard                                                  340
# Fare                                                              28654.9077
# dtype: object

# %%
titanic_df.dropna()
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0      male  22.0                        1                        0   7.2500
# 1    female  38.0                        1                        0  71.2833
# 2    female  26.0                        0                        0   7.9250
# 3    female  35.0                        1                        0  53.1000
# 4      male  35.0                        0                        0   8.0500
# ..      ...   ...                      ...                      ...      ...
# 882    male  27.0                        0                        0  13.0000
# 883  female  19.0                        0                        0  30.0000
# 884  female   7.0                        1                        2  23.4500
# 885    male  26.0                        0                        0  30.0000
# 886    male  32.0                        0                        0   7.7500
#
# [887 rows x 8 columns]

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# ## Titanic dataset 2

# %%
import pandas as pd
import openpyxl as op

titanic = pd.read_excel("D:\Machine_Learning\Data sets\Titanic.xlsx")

titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
titanic.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
titanic["Age"].mean()
# Out:
# 30.272590361445783

# %%
titanic["Fare"].mean()
# Out:
# 35.627188489208635

# %%
titanic["Age"].median()
# Out:
# 27.0

# %%
titanic["Fare"].median()
# Out:
# 14.4542

# %%
titanic["Age"].mode()
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
titanic["Fare"].mode()
# Out:
# 0    7.75
# Name: Fare, dtype: float64

# %%
titanic["Fare"].head(10)
# Out:
# 0     7.8292
# 1     7.0000
# 2     9.6875
# 3     8.6625
# 4    12.2875
# 5     9.2250
# 6     7.6292
# 7    29.0000
# 8     7.2292
# 9    24.1500
# Name: Fare, dtype: float64

# %%
titanic[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  332.000000  417.000000
# mean    30.272590   35.627188
# std     14.181209   55.907576
# min      0.170000    0.000000
# 25%     21.000000    7.895800
# 50%     27.000000   14.454200
# 75%     39.000000   31.500000
# max     76.000000  512.329200

# %% [markdown]
# ## Aggregating statistics grouped by category

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic[['Sex', 'Age', 'Fare']].groupby('Sex').mean()
# Out:
#               Age       Fare
# Sex
# female  30.272362  49.747699
# male    30.272732  27.527877

# %%
titanic.groupby('Pclass').mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7148\3340069855.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   titanic.groupby('Pclass').mean()
#         PassengerId        Age     SibSp     Parch       Fare
# Pclass
# 1       1098.224299  40.918367  0.476636  0.383178  94.280297
# 2       1117.935484  28.777500  0.376344  0.344086  22.202104
# 3       1094.178899  24.027945  0.463303  0.417431  12.459678

# %%
titanic[['Pclass', 'Sex', 'Fare']].groupby('Sex').mean()
# Out:
#           Pclass       Fare
# Sex
# female  2.144737  49.747699
# male    2.334586  27.527877

# %%
titanic.groupby(['Sex', 'Pclass'])['Age'].mean()
# Out:
# Sex     Pclass
# female  1         41.333333
#         2         24.376552
#         3         23.073400
# male    1         40.520000
#         2         30.940678
#         3         24.525104
# Name: Age, dtype: float64

# %%
titanic['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
titanic['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
titanic['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
titanic['SibSp'].value_counts()
# Out:
# 0    283
# 1    110
# 2     14
# 3      4
# 4      4
# 8      2
# 5      1
# Name: SibSp, dtype: int64

# %%
titanic['Parch'].value_counts()
# Out:
# 0    324
# 1     52
# 2     33
# 3      3
# 4      2
# 9      2
# 6      1
# 5      1
# Name: Parch, dtype: int64

# %%
print(titanic.groupby('Pclass')['Sex'].value_counts())
# Out:
# Pclass  Sex
# 1       male       57
#         female     50
# 2       male       63
#         female     30
# 3       male      146
#         female     72
# Name: Sex, dtype: int64

# %% [markdown]
# ## Reshape the layout of table

# %%
titanic.sort_values(by= ['Age']).head(10)
# Out:
#      PassengerId  Pclass                                     Name     Sex  \
# 354         1246       3  Dean, Miss. Elizabeth Gladys Millvina""  female
# 201         1093       3  Danbom, Master. Gilbert Sigvard Emanuel    male
# 281         1173       3           Peacock, Master. Alfred Edward    male
# 307         1199       3                Aks, Master. Philip Frank    male
# 250         1142       2                    West, Miss. Barbara J  female
# 263         1155       3             Klasen, Miss. Gertrud Emilia  female
# 117         1009       3          Sandstrom, Miss. Beatrice Irene  female
# 296         1188       2                    Laroche, Miss. Louise  female
# 89           981       2              Wells, Master. Ralph Lester    male
# 284         1176       3              Rosblom, Miss. Salli Helena  female
#
#       Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# 354  0.17      1      2           C.A. 2315  20.5750   NaN        S
# 201  0.33      0      2              347080  14.4000   NaN        S
# 281  0.75      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S
# 307  0.83      0      1              392091   9.3500   NaN        S
# 250  0.92      1      2          C.A. 34651  27.7500   NaN        S
# 263  1.00      1      1              350405  12.1833   NaN        S
# 117  1.00      1      1             PP 9549  16.7000    G6        S
# 296  1.00      1      2       SC/Paris 2123  41.5792   NaN        C
# 89   2.00      1      1               29103  23.0000   NaN        S
# 284  2.00      1      1              370129  20.2125   NaN        S

# %%
titanic.sort_values(by= ['Fare','Age']).head(10)
# Out:
#      PassengerId  Pclass                                    Name     Sex  \
# 372         1264       1                 Ismay, Mr. Joseph Bruce    male
# 266         1158       1   Chisholm, Mr. Roderick Robert Crispin    male
# 21           913       3               Olsen, Master. Artur Karl    male
# 116         1008       3                        Thomas, Mr. John    male
# 133         1025       3                   Thomas, Mr. Charles P    male
# 232         1124       3                 Wiklund, Mr. Karl Johan    male
# 291         1183       3  Daly, Miss. Margaret Marcella Maggie""  female
# 1            893       3        Wilkes, Mrs. James (Ellen Needs)  female
# 163         1055       3                      Pearce, Mr. Ernest    male
# 325         1217       3                          Assam, Mr. Ali    male
#
#       Age  SibSp  Parch              Ticket    Fare        Cabin Embarked
# 372  49.0      0      0              112058  0.0000  B52 B54 B56        S
# 266   NaN      0      0              112051  0.0000          NaN        S
# 21    9.0      0      1             C 17368  3.1708          NaN        S
# 116   NaN      0      0                2681  6.4375          NaN        C
# 133   NaN      1      0                2621  6.4375          NaN        C
# 232  21.0      1      0             3101266  6.4958          NaN        S
# 291  30.0      0      0              382650  6.9500          NaN        Q
# 1    47.0      1      0              363272  7.0000          NaN        S
# 163   NaN      0      0              343271  7.0000          NaN        S
# 325  23.0      0      0  SOTON/O.Q. 3101309  7.0500          NaN        S

# %%
titanic.sort_values(by= ['Pclass'], ascending=False).head(10)
# Out:
#      PassengerId  Pclass                                       Name     Sex  \
# 0            892       3                           Kelly, Mr. James    male
# 232         1124       3                    Wiklund, Mr. Karl Johan    male
# 249         1141       3  Khalil, Mrs. Betros (Zahie Maria" Elias)"  female
# 244         1136       3  Johnston, Master. William Arthur Willie""    male
# 243         1135       3                         Hyman, Mr. Abraham    male
# 237         1129       3                        Baccos, Mr. Raffull    male
# 235         1127       3                     Vendel, Mr. Olof Edvin    male
# 233         1125       3                       Linehan, Mr. Michael    male
# 228         1120       3                  Everett, Mr. Thomas James    male
# 214         1106       3     Andersson, Miss. Ida Augusta Margareta  female
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 0    34.5      0      0      330911   7.8292   NaN        Q
# 232  21.0      1      0     3101266   6.4958   NaN        S
# 249   NaN      1      0        2660  14.4542   NaN        C
# 244   NaN      1      2  W./C. 6607  23.4500   NaN        S
# 243   NaN      0      0        3470   7.8875   NaN        S
# 237  20.0      0      0        2679   7.2250   NaN        C
# 235  20.0      0      0      350416   7.8542   NaN        S
# 233   NaN      0      0      330971   7.8792   NaN        Q
# 228  40.5      0      0   C.A. 6212  15.1000   NaN        S
# 214  38.0      4      2      347091   7.7750   NaN        S

# %% [markdown]
# ## Plotting

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
titanic['Fare'].head(20).plot(kind= 'area')
# Out:
# <Axes: >

# %%
titanic['Fare'].head().plot(kind= 'bar')
# Out:
# <Axes: >

# %% [markdown]
# # Thank you!
